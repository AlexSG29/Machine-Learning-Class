# %% [markdown]
# vamos a suponer que yo voy a definir unos datos

# %%
import numpy as np

x = np.arange(-30, 30, 0.5)
x
# Out:
# array([-30. , -29.5, -29. , -28.5, -28. , -27.5, -27. , -26.5, -26. ,
#        -25.5, -25. , -24.5, -24. , -23.5, -23. , -22.5, -22. , -21.5,
#        -21. , -20.5, -20. , -19.5, -19. , -18.5, -18. , -17.5, -17. ,
#        -16.5, -16. , -15.5, -15. , -14.5, -14. , -13.5, -13. , -12.5,
#        -12. , -11.5, -11. , -10.5, -10. ,  -9.5,  -9. ,  -8.5,  -8. ,
#         -7.5,  -7. ,  -6.5,  -6. ,  -5.5,  -5. ,  -4.5,  -4. ,  -3.5,
#         -3. ,  -2.5,  -2. ,  -1.5,  -1. ,  -0.5,   0. ,   0.5,   1. ,
#          1.5,   2. ,   2.5,   3. ,   3.5,   4. ,   4.5,   5. ,   5.5,
#          6. ,   6.5,   7. ,   7.5,   8. ,   8.5,   9. ,   9.5,  10. ,
#         10.5,  11. ,  11.5,  12. ,  12.5,  13. ,  13.5,  14. ,  14.5,
#         15. ,  15.5,  16. ,  16.5,  17. ,  17.5,  18. ,  18.5,  19. ,
#         19.5,  20. ,  20.5,  21. ,  21.5,  22. ,  22.5,  23. ,  23.5,
#         24. ,  24.5,  25. ,  25.5,  26. ,  26.5,  27. ,  27.5,  28. ,
#         28.5,  29. ,  29.5])

# %%
# construimos un nuevo y1 
ruido = np.random.rand(len(x))*40
y1 = 4*x + 6
y2 = y1 + ruido # el del ruido

# el ruido lo que hace es agregarle una variacion aleatoria a cada punto de y1
# esto se usa para simular datos reales, que siempre tienen algun grado de incertidumbre o variabilidad.

# %%
import matplotlib.pyplot as plt

#vamos a graficas ambas series de datos y1 e y2
#ambos en la misma grafica

plt.scatter(x, y1, color='blue', label='y1 (sin ruido)')
plt.scatter(x, y2, color='red', label='y2 (con ruido)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparación de y1 e y2')
plt.legend()
plt.show()

# %%
# regresion logistica con sigma

sigma  = lambda z: 1 / (1 + np.exp(-z))
z = np.linspace(-10, 10, 100)
plt.plot(z, sigma(z))
plt.title('Función Sigmoide')
plt.xlabel('z')
plt.ylabel('σ(z)')
plt.grid()
plt.show()
